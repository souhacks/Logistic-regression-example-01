# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data = pd.read_csv('advertising.csv')
data.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad
# 0  2016-03-27 00:53:11              0
# ...

# %%
data
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   object
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.2+ KB

# %%
df = data.copy()

# %%
clean = df.columns.str.lower().str.replace(" ","_")

# %%
df.columns = clean
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   daily_time_spent_on_site  1000 non-null   float64
#  1   age                       1000 non-null   int64
#  2   area_income               1000 non-null   float64
#  3   daily_internet_usage      1000 non-null   float64
#  4   ad_topic_line             1000 non-null   object
#  5   city                      1000 non-null   object
#  6   male                      1000 non-null   int64
#  7   country                   1000 non-null   object
#  8   timestamp                 1000 non-null   object
#  9   clicked_on_ad             1000 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.2+ KB

# %%
df.shape
# Out:
# (1000, 10)

# %%
df.columns
# Out:
# Index(['daily_time_spent_on_site', 'age', 'area_income',
#        'daily_internet_usage', 'ad_topic_line', 'city', 'male', 'country',
#        'timestamp', 'clicked_on_ad'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# daily_time_spent_on_site    0
# age                         0
# area_income                 0
# daily_internet_usage        0
# ad_topic_line               0
# city                        0
# male                        0
# country                     0
# timestamp                   0
# clicked_on_ad               0
# dtype: int64

# %%
sns.heatmap(df.isna(), cmap="cool")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(), cmap="cool", annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
df['age'].value_counts()
# Out:
# 31    60
# 36    50
# 28    48
# 29    48
# 33    43
# 35    39
# 30    39
# 34    39
# 32    38
# 26    37
# 38    37
# 37    36
# 40    36
# 27    33
# 41    32
# 45    30
# 39    30
# 25    27
# 42    26
# 43    23
# 44    21
# 24    21
# 50    20
# 23    19
# 46    18
# 49    18
# 48    16
# 52    15
# 47    13
# 22    13
# 51    12
# 53    10
# 54     9
# 55     7
# 20     6
# 21     6
# 57     6
# 19     6
# 60     4
# 58     4
# 56     2
# 59     2
# 61     1
# Name: age, dtype: int64

# %%
# showing income vs age
plt.figure(figsize=(12,4))
sns.countplot(x='age', data = df, palette='afmhot')
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
sns.set_style('whitegrid')
df['age'].hist(bins=30)
plt.show()

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,4))
sns.barplot(x='age', y='area_income', data=df, ci=None)
# Out:
# <AxesSubplot:xlabel='age', ylabel='area_income'>

# %%
bins = np.arange(10,70,10)
df['bin'] = pd.cut(df['age'], bins)
df.head()
# Out:
#    daily_time_spent_on_site  age  area_income  daily_internet_usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            ad_topic_line            city  male     country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              timestamp  clicked_on_ad       bin
# 0  2016-03-27 00:53:11              0  (30, 40]
# ...

# %%
df['bin'].value_counts()
# Out:
# (30, 40]    408
# (20, 30]    291
# (40, 50]    217
# (50, 60]     71
# (10, 20]     12
# Name: bin, dtype: int64

# %%
sns.barplot(x='bin', y='area_income', data=df, ci=None, palette='cool')
# Out:
# <AxesSubplot:xlabel='bin', ylabel='area_income'>

# %%
sns.barplot(x='bin', y='daily_time_spent_on_site', hue='male', data=df, ci=None, palette='cool')
# Out:
# <AxesSubplot:xlabel='bin', ylabel='daily_time_spent_on_site'>

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])
df['hour']  = df['timestamp'].dt.hour
df.head()
# Out:
#    daily_time_spent_on_site  age  area_income  daily_internet_usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            ad_topic_line            city  male     country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#             timestamp  clicked_on_ad       bin  hour
# ...

# %%
df['year'] = df['timestamp'].dt.year
df['month'] = df['timestamp'].dt.month
df['day'] = df['timestamp'].dt.day
df.head()
# Out:
#    daily_time_spent_on_site  age  area_income  daily_internet_usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            ad_topic_line            city  male     country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#             timestamp  clicked_on_ad       bin  hour  year  month  day
# ...

# %%
df['country'].value_counts()
# Out:
# France                                                 9
# Czech Republic                                         9
# Peru                                                   8
# Turkey                                                 8
# Greece                                                 8
#                                                       ..
# Romania                                                1
# British Indian Ocean Territory (Chagos Archipelago)    1
# Germany                                                1
# Aruba                                                  1
# Lesotho                                                1
# Name: country, Length: 237, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   daily_time_spent_on_site  1000 non-null   float64
#  1   age                       1000 non-null   int64
#  2   area_income               1000 non-null   float64
#  3   daily_internet_usage      1000 non-null   float64
#  4   ad_topic_line             1000 non-null   object
#  5   city                      1000 non-null   object
#  6   male                      1000 non-null   int64
#  7   country                   1000 non-null   object
#  8   timestamp                 1000 non-null   datetime64[ns]
#  9   clicked_on_ad             1000 non-null   int64
#  10  bin                       999 non-null    category
#  11  hour                      1000 non-null   int64
#  12  year                      1000 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['daily_time_spent_on_site', 'age', 'area_income',
#        'daily_internet_usage', 'ad_topic_line', 'city', 'male', 'country',
#        'timestamp', 'clicked_on_ad', 'bin', 'hour', 'year', 'month', 'day'],
#       dtype='object')

# %%
# dependent and independent variables:
X = df[['daily_time_spent_on_site', 'age', 'area_income',
       'daily_internet_usage', 'male', 'hour', 'year', 'month', 'day']]

# %%
Y = df[['clicked_on_ad']]

# %%
X
# Out:
#      daily_time_spent_on_site  age  area_income  daily_internet_usage  male  \
# 0                       68.95   35     61833.90                256.09     0
# 1                       80.23   31     68441.85                193.77     1
# 2                       69.47   26     59785.94                236.50     0
# 3                       74.15   29     54806.18                245.89     1
# 4                       68.37   35     73889.99                225.58     0
# ..                        ...  ...          ...                   ...   ...
# 995                     72.97   30     71384.57                208.58     1
# 996                     51.30   45     67782.17                134.42     1
# 997                     51.63   51     42415.72                120.37     1
# 998                     55.55   19     41920.79                187.95     0
# 999                     45.01   26     29875.80                178.35     0
#
#      hour  year  month  day
# ...

# %%
Y
# Out:
#      clicked_on_ad
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ..             ...
# 995              1
# 996              1
# 997              1
# 998              0
# 999              1
#
# [1000 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.4, random_state=42)
print('X_train', X_train.shape)
print('X_test', X_test.shape)
print('Y_train', Y_train.shape)
print('Y_test', Y_test.shape)
# Out:
# X_train (600, 9)
# X_test (400, 9)
# Y_train (600, 1)
# Y_test (400, 1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train, Y_train)
# Out:
# C:\ProgramData\anaconda\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
prediction = lr.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
print(confusion_matrix(Y_test, prediction))
# Out:
# [[186   5]
#  [  9 200]]

# %%
tp, fp, fn, tn = confusion_matrix(Y_test, prediction).ravel()
tp, fp, fn, tn
# Out:
# (186, 5, 9, 200)

# %%
print(classification_report(Y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       191
#            1       0.98      0.96      0.97       209
#
#     accuracy                           0.96       400
#    macro avg       0.96      0.97      0.96       400
# weighted avg       0.97      0.96      0.97       400
